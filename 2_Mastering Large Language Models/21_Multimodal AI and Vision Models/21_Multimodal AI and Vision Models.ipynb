# %% [markdown]
# # Multimodal AI
#
# resource: https://github.com/BradyFU/Awesome-Multimodal-Large-Language-Models
#
# text, images, audio, video
#
# use case for vision model
# - image captioning
# - create an image captioning system using vision models and also using deep learning (task)
#
# - fall detection using vision model
# - visual question answering

# %%
Applications
- autonomous vehicles (tesla): https://www.youtube.com/watch?v=fKXztwtXaGo

- virtual assistants: sora, chatGPT
- content generation

# %%
examples for multimodal models: dall-e, gpt-4o, sora

# %% [markdown]
# ### Architecture Old one:
#
# ![image.png](attachment:8f50b732-aa5c-4fb6-b46c-0f069d6bfe20.png)

# %% [markdown]
# ## LLM Architecture
#
# ![image.png](attachment:2313ab16-6381-42a0-a1aa-85534adbe3b9.png)

# %% [markdown]
# ## build multimodal models using these datasets:
#
# https://cocodataset.org/#explore
#
# https://laion.ai/blog/laion-400-open-dataset/
#
# https://github.com/rom1504/clip-retrieval
#
# https://homes.cs.washington.edu/~ranjay/visualgenome/index.html

# %% [markdown]
# # Vision Models

# %%
images and videos

early models: HOG, SIFT

CNN - AlexNet, ResNet, Inception

Transformer - ViT

# %% [markdown]
# Dataset for tiny images: https://www.cs.toronto.edu/~kriz/cifar.html

# %% [markdown]
# # Task
#
# ## 1 - image captioning
#
# create an image captioning system using vision models
#
#
# ## 2 - Multimodal AI system
#
# - can process text and images
#
# https://huggingface.co/Salesforce/blip-image-captioning-base
#
# - front-end of web interface
# - create an architecture using excalidraw

# %% [markdown]
# # Why?
#
# ## market/ship your work
#
# - deadline: Sunday (29th June 2025)
